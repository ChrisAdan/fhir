# %%
import pandas as pd
import requests, json

# %%
base_url = 'https://hapi.fhir.org/baseR4/'
num = 10
patient_resp = requests.get(f'{base_url}Patient?_count={num}')
# Out:
# _content
# status_code
# headers
# url
# history
# encoding
# reason
# cookies
# elapsed
# request

# %%
patient_resp.json()['entry']
# Out:
# [{'fullUrl': 'https://hapi.fhir.org/baseR4/Patient/597117',
#   'resource': {'resourceType': 'Patient',
#    'id': '597117',
#    'meta': {'versionId': '1',
#     'lastUpdated': '2020-02-03T15:24:07.790+00:00',
#     'source': '#eKD4HA4iUASJ1c34'},
#    'text': {'status': 'generated'},
#    'identifier': [{'use': 'official',
#      'system': 'urn:oid:2.16.528.1',
#      'value': '62jlb'},
#     {'use': 'usual',
#      'system': 'urn:oid:2.16.840.1.113883.2.4.6.1',
#      'value': '17-0112278'}],
#    'name': [{'use': 'official',
#      'text': 'Serena Mustermann',
#      'family': 'Mustermann',
#      'given': ['Serena']}],
#    'address': [{'use': 'home',
#      'type': 'physical',
#      'text': 'Musterweg 42, Hinterhof 2. Etage, 10787 Berlin, Deutschland',
#      'line': ['Musterweg 42', 'Hinterhof 2. Etage'],
#      '_line': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/iso21090-ADXP-streetName',
#          'valueString': 'Musterweg'},
# ...
